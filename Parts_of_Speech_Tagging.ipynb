# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
nltk.pos_tag_sents("You are the bane of my existence and the object of my desires")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c6e19a454429> in <cell line: 1>()
# ----> 1 nltk.pos_tag_sents("You are the bane of my existence and the object of my desires")
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/__init__.py in pos_tag_sents(sentences, tagset, lang)
#     182     """
#     183     tagger = _get_tagger(lang)
# --> 184     return [_pos_tag(sent, tagset, tagger, lang) for sent in sentences]
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/__init__.py in <listcomp>(.0)
#     182     """
#     183     tagger = _get_tagger(lang)
# --> 184     return [_pos_tag(sent, tagset, tagger, lang) for sent in sentences]
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/__init__.py in _pos_tag(tokens, tagset, tagger, lang)
#     118     # Throws Error if tokens is of string type
#     119     elif isinstance(tokens, str):
# ...
